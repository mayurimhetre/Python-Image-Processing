# %%
import numpy as np 
import matplotlib.pyplot as plt
import cv2

# %%
a = cv2.imread('00-puppy.jpg')

# %%
a ####################  cv2 image having channels in order B G R
# Out:
# array([[[78, 81, 95],
#         [80, 83, 97],
#         [81, 84, 98],
#         ...,
#         [22, 27, 25],
#         [22, 27, 25],
#         [22, 27, 25]],
#
#        [[78, 81, 95],
#         [79, 82, 96],
#         [79, 82, 96],
#         ...,
#         [22, 27, 25],
#         [22, 27, 25],
#         [22, 27, 25]],
#
#        [[78, 81, 95],
#         [77, 80, 94],
#         [77, 80, 94],
#         ...,
#         [22, 27, 25],
#         [22, 27, 25],
#         [22, 27, 25]],
#
#        ...,
#
#        [[20, 29, 19],
#         [21, 30, 20],
#         [21, 30, 20],
#         ...,
#         [22, 30, 23],
#         [23, 31, 24],
#         [23, 31, 24]],
#
#        [[21, 30, 20],
#         [21, 30, 20],
#         [20, 29, 19],
#         ...,
#         [22, 30, 23],
#         [23, 31, 24],
#         [23, 31, 24]],
#
#        [[21, 30, 20],
#         [20, 29, 19],
#         [20, 29, 19],
#         ...,
#         [22, 30, 23],
#         [23, 31, 24],
#         [23, 31, 24]]], dtype=uint8)

# %%
cv2.imshow('names',a)

# %%
plt.imshow(a)

# %%
b = cv2.cvtColor(a,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(cv2.cvtColor(a,cv2.COLOR_BGR2RGB))

# %%
img_gray = cv2.imread('00-puppy.jpg',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
img_gray.shape ################# gray scale image -- no channels
# Out:
# (1300, 1950)

# %%
new_image = cv2.resize(b,(1000,700))

# %%
plt.imshow(new_image)

# %%
new_image.shape
# Out:
# (700, 1000, 3)

# %%
c  = cv2.flip(b,0)

# %%
plt.imshow(c)

# %%
c  = cv2.flip(b,1)
plt.imshow(c)

# %%
cv2.imwrite('new_flip.jpg',c)         ######### to save a new image
# Out:
# True

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(144)
ax.imshow(a)
ax.imshow(b)

# %%
fig = plt.figure(figsize=(12,10))
plt.subplot(1,4,1)
plt.imshow(a)
plt.subplot(1,4,2)
plt.imshow(b)
plt.subplot(1,4,3)
plt.imshow(c)
plt.subplot(1,4,4)
plt.imshow(cv2.flip(b,0))
